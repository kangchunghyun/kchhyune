# %%
from PIL import Image

# %%
# ICO 파일 열기
ico_image = Image.open(input(":"))
# Out:
# :\\192.168.2.21\NFS_Chunghyun\4_Sample\2_Test Sample\3_CDR\Sample\v3.1\ICO\ICO_CASE_NONE.ico

# %%
# ICO 파일의 크기 및 모드 확인
print("이미지 크기:", ico_image.size)
print("이미지 모드:", ico_image.mode)
ico_image.info["test"] = "kangjihan"
pixel_data = list(ico_image.getdata())
print(pixel_data)
# Out:
# 이미지 크기: (256, 256)
# 이미지 모드: RGBA
# ...

# %%
# ICO 파일 저장
ico_image.save(input(""))
# Out:
# \\192.168.2.21\NFS_Chunghyun\4_Sample\2_Test Sample\3_CDR\Sample\v3.1\ICO\ICO_CASE_METADATA.ico

# %%
# 이미지 닫기
ico_image.close()
